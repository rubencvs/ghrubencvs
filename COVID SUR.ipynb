# %%
import pandas as pd
import geopandas as gpd
import geopy
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import matplotlib.pyplot as plt
import folium
from folium.plugins import FastMarkerCluster
from folium.plugins import MarkerCluster

# %%
locator = Nominatim(user_agent="myGeocoder")
location = locator.geocode("Hospital El Pino, San Bernardo, Chile")

# %%
print(location.address)
print("Latitude = {}, Longitude = {}".format(location.latitude, location.longitude))
# Out:
# Hospital El Pino, Coperitivista Sergio Aguilero, San Bernardo, Provincia de Maipo, Región Metropolitana de Santiago, 8051557, Chile
# Latitude = -33.58472935, Longitude = -70.67480915038735

# %%
pino_file_path = 'Downloads/ML/Data/CoronavirusElPinoGeo.csv'

pino_data = pd.read_csv(pino_file_path) 

pino_data.head()
# Out:
#    ID    PAPMIDOB  PAPMISexDR         PAPERStName     CTCITDesc PAPMIDeceased  \
# 0   1  01/06/1995           2    LOS NOGALES 9857     El Bosque             N
# 1  12  01/08/1949           2         NOGALES 57   San Bernardo             N
# 2  18  12/09/1955           1  PJE ROLECHA 15331   San Bernardo             N
# 3  19  22/07/1997           1    SAN CARLOS 8979    La Cisterna             N
# 4  20  21/06/1997           2     SAN MIGUEL 1915  San Bernardo             N
#
#   PAPMIDeceasedDate   MRDIADate                               Direccion  \
# 0               NaN  31/05/2020       LOS NOGALES 9857,El Bosque, Chile
# 1               NaN  31/05/2020         NOGALES 57 ,San Bernardo, Chile
# 2               NaN  31/05/2020  PJE ROLECHA 15331 ,San Bernardo, Chile
# 3               NaN  31/05/2020     SAN CARLOS 8979 ,La Cisterna, Chile
# 4               NaN  31/05/2020     SAN MIGUEL 1915,San Bernardo, Chile
#
#                                             location  \
# ...

# %%
print("SDSR")
# Out:
# SDSR

# %%
print("COVID")
# Out:
# COVID

# %%
# Define a map centered around Santiago
santiago_map = folium.Map(location=[-33.58472935,-70.67480915038735], zoom_start=14)

#Mark the center
for index, row in pino_data.iterrows():
    linea = row['point']
    labelpp = row['ID']
    linea = linea.replace("(", "") 
    linea = linea.replace(")", "")
    loglat = linea.split(",")   
    micolor='red'
    deceased = row['PAPMIDeceased']
    if deceased=='Y':
        micolor = 'black'
    folium.CircleMarker(
                [loglat[0],loglat[1]],
                radius=3,
                color=micolor,
                fill=True,
                popup=labelpp,
                fill_color='darkred',
                fill_opacity=0.6
            ).add_to(santiago_map)

    
santiago_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
